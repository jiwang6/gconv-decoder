# %%
# Impor tensorflow and numpy
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import math as m
import time
# For validation
from sklearn.metrics import confusion_matrix
import itertools



# For plotting
from matplotlib import pyplot as plt

# Add the library to the system path
import os,sys
se2cnn_source =  os.path.join(os.getcwd(),'..')
if se2cnn_source not in sys.path:
    sys.path.append(se2cnn_source)

# Import the library
import se2cnn.layers



from Datavis import visualize_observation, pp_code_X, pp_code_Z
# Out:
# WARNING:tensorflow:From c:\Users\jimzw\miniconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\compat\v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
distance = 9
percent_error = 155

dataset = np.load(f'test-datasets/HL_data_{distance}_{percent_error}_70000.npy')

from Datagen import generate_single_observation

observation = dataset[0]#generate_single_observation(useed=1)

# all but last 4
plot_data = observation[:-4]

syndrome = plot_data[:2*distance**2]
noise = plot_data[2*distance**2:]

decoding = observation[-4:]



visualize_observation(plot_data)
print(decoding)
# Out:
# distance: 5
# [1 1 1 1]
