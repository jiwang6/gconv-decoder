# %%
from Datavis import visualize_observation
import random 
import numpy as np
# read .npy to numpy array
data = np.load('test_datasets//MC_data_5_10_70000.npy')

observation = data[0]

# visualize observation
visualize_observation(observation)
# Out:
# 5
